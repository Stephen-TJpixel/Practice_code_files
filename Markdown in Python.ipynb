# %% [markdown]
# # The Html way

# %% [markdown]
# # Header 1, title
# ## Header 2, Major headings
# ### Header 3, subheadings
# #### Header 4
# ##### Header 5
# ###### Header 6

# %% [markdown]
# ### Blockquotes (>)- holds large chunk of text and are generally indented
# > This is good

# %% [markdown]
# <blockquote>text</blockquote

# %% [markdown]
# #### Mathematical symbols (\dollarsymb\sqrt(4)dollar...)
#
# \$\sqrt{4}$

# %% [markdown]
# ### Line Break
# This is how we can use the <br> tag

# %% [markdown]
# ### Bold italic text
# <b>This is is a bold text</b>
#
# <i>Italic</i>
# <hr>

# %% [markdown]
# ### ordered list
# <ol>
#     <li>Too much pepper= pepper</li>
#     <li>Too much salt= salty</li>
#     <li>Too much oil=oily</li>
#     <li>Too much onions= ??</li>
#
# </ol>

# %% [markdown]
# ### Unordered list
# <l>
#     <li>Too much pepper= pepper</li>
#     <li>Too much salt= salty</li>
#     <li>Too much oil=oily</li>
#     <li>Too much onions= ??</li>
#
# </ul>

# %% [markdown]
# ### Tables
# <table style="width:20%">
#     <tr>
#         <th>Name</th>
#         <th>Adress</th>
#         <th>Salary</th>
#     </tr>
#     <tr>
#         <td>Hanna</td>
#         <td>New York City</td>
#         <td>4000</td>
#     </tr>
#     <tr>
#         <td>Adam</td>
#         <td>Sweden</td>
#         <td>6000</td>
#     </tr>
#      <tr>
#         <td>Santos</td>
#         <td>Portugal</td>
#         <td>6500</td>
#     </tr>
#
#
# </table>

# %% [markdown]
# ### Images![IMG_20191214_172516_659.jpg](attachment:IMG_20191214_172516_659.jpg)
